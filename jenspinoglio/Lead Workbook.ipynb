# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import geopandas as gpd

# %%
lead = pd.read_csv("sequential_cleaned+geo_cleaned.csv")
lead
# Out:
#      Date Sampled               Address  1st Draw  2nd Draw  3rd Draw  \
# 0        9/4/2019      100XX S Bell Ave      1.52      1.37      1.59
# 1       7/16/2016   100XX S Calhoun Ave      3.70      2.62      8.83
# 2      12/17/2019   100XX S Calumet Ave      4.02      5.35      6.97
# 3       7/14/2021  100XX S Carpenter St     14.00     11.00      8.83
# 4      12/14/2019  100XX S Carpenter St      9.54      7.31      6.95
# ...           ...                   ...       ...       ...       ...
# 1803    1/26/2022     9XX W Gunnison St      6.20      7.00      7.20
# 1804    1/19/2019          XX S Oakley       2.01      2.38      3.07
# 1805   11/22/2021          XX W 78Th St     11.00     11.40      8.06
# 1806   10/28/2021          XX W 81St St      4.41      5.43      4.96
# 1807    6/18/2019        XX W Burton Pl      5.79      5.23      5.38
#
#       4th Draw  5th Draw  6th Draw  7th Draw  8th Draw  ...  \
# 0         2.53      2.44      1.90      2.45      2.92  ...
# ...

# %%
lead.groupby("neighbourhood")["1st Draw"].describe()
px.box(lead,y="1st Draw",x="neighbourhood")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qh/z06pkpjj4yz6tvp0wqdsrkfw0000gn/T/ipykernel_1717/4279945634.py in <module>
#       1 lead.groupby("neighbourhood")["1st Draw"].describe()
# ----> 2 px.box(lead,y="1st Draw",x="neighbourhood")
#
# NameError: name 'px' is not defined

# %%
lead2 = lead.groupby("neighbourhood")["1st Draw"].median().to_frame().reset_index()
px.bar(lead2,x="neighbourhood",y="1st Draw")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qh/z06pkpjj4yz6tvp0wqdsrkfw0000gn/T/ipykernel_1717/110667701.py in <module>
#       1 lead2 = lead.groupby("neighbourhood")["1st Draw"].median().to_frame().reset_index()
# ----> 2 px.bar(lead2,x="neighbourhood",y="1st Draw")
#
# NameError: name 'px' is not defined

# %%
lead.lat=lead.lat.astype("float")
lead.lon=lead.lon.astype("float")

# %%
lead.columns
# Out:
# Index(['Date Sampled', 'Address', '1st Draw', '2nd Draw', '3rd Draw',
#        '4th Draw', '5th Draw', '6th Draw', '7th Draw', '8th Draw', '9th Draw',
#        '10th Draw', '11th Draw', '3 Minute', '5 Minute', '7 Minute',
#        '10 Minute', '15 Minute', '20 Minute', 'geodata', 'place_id',
#        'osm_type', 'osm_id', 'boundingbox', 'lat', 'lon', 'display_name',
#        'class', 'type', 'importance', 'road', 'neighbourhood', 'suburb'],
#       dtype='object')

# %%
lead_geo = gpd.GeoDataFrame(
    lead, geometry=gpd.points_from_xy(lead.lon, lead.lat))
lead_geo
# Out:
#      Date Sampled               Address  1st Draw  2nd Draw  3rd Draw  \
# 0        9/4/2019      100XX S Bell Ave      1.52      1.37      1.59
# 1       7/16/2016   100XX S Calhoun Ave      3.70      2.62      8.83
# 2      12/17/2019   100XX S Calumet Ave      4.02      5.35      6.97
# 3       7/14/2021  100XX S Carpenter St     14.00     11.00      8.83
# 4      12/14/2019  100XX S Carpenter St      9.54      7.31      6.95
# ...           ...                   ...       ...       ...       ...
# 1803    1/26/2022     9XX W Gunnison St      6.20      7.00      7.20
# 1804    1/19/2019          XX S Oakley       2.01      2.38      3.07
# 1805   11/22/2021          XX W 78Th St     11.00     11.40      8.06
# 1806   10/28/2021          XX W 81St St      4.41      5.43      4.96
# 1807    6/18/2019        XX W Burton Pl      5.79      5.23      5.38
#
#       4th Draw  5th Draw  6th Draw  7th Draw  8th Draw  ...        lat  \
# ...
