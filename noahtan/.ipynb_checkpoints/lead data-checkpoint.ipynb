# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sequential_cleaned+geo_cleaned.csv")

# %%
df
# Out:
#      Date Sampled               Address  1st Draw  2nd Draw  3rd Draw  \
# 0        9/4/2019      100XX S Bell Ave      1.52      1.37      1.59
# 1       7/16/2016   100XX S Calhoun Ave      3.70      2.62      8.83
# 2      12/17/2019   100XX S Calumet Ave      4.02      5.35      6.97
# 3       7/14/2021  100XX S Carpenter St     14.00     11.00      8.83
# 4      12/14/2019  100XX S Carpenter St      9.54      7.31      6.95
# ...           ...                   ...       ...       ...       ...
# 1803    1/26/2022     9XX W Gunnison St      6.20      7.00      7.20
# 1804    1/19/2019          XX S Oakley       2.01      2.38      3.07
# 1805   11/22/2021          XX W 78Th St     11.00     11.40      8.06
# 1806   10/28/2021          XX W 81St St      4.41      5.43      4.96
# 1807    6/18/2019        XX W Burton Pl      5.79      5.23      5.38
#
#       4th Draw  5th Draw  6th Draw  7th Draw  8th Draw  ...  \
# 0         2.53      2.44      1.90      2.45      2.92  ...
# 1        13.80     13.20     13.60     12.30     11.80  ...
# 2         6.55     17.70     16.60     12.10     11.60  ...
# 3         8.12      8.69      7.14     11.00      7.51  ...
# 4         5.63      4.91      7.15     12.40     13.10  ...
# ...        ...       ...       ...       ...       ...  ...
# 1803      8.90      9.80      9.70      9.40      9.40  ...
# 1804      3.74      3.94      4.15      4.08      4.43  ...
# 1805      8.49     21.40     28.60     29.30     19.70  ...
# 1806      3.87      4.80      4.93      9.11      8.83  ...
# 1807      5.38      5.16      5.30      6.11      7.97  ...
#
#                                             boundingbox        lat        lon  \
# 0     ['41.8298961', '41.8303315', '-87.6813753', '-...  41.830258 -87.681374
# 1     ['41.7027818', '41.7081424', '-87.5620899', '-...  41.704591 -87.562038
# 2     ['41.7801361', '41.7803908', '-87.6172609', '-...  41.780298 -87.617220
# 3     ['41.8694719', '41.8726581', '-87.6533123', '-...  41.871438 -87.653266
# 4     ['41.8694719', '41.8726581', '-87.6533123', '-...  41.871438 -87.653266
# ...                                                 ...        ...        ...
# 1803  ['41.9702296', '41.9702507', '-87.6610757', '-...  41.970239 -87.660464
# 1804                                                NaN        NaN        NaN
# 1805  ['41.7515562', '41.7516078', '-87.7073245', '-...  41.751585 -87.705499
# 1806  ['41.7452691', '41.7453035', '-87.734934', '-8...  41.745295 -87.733959
# 1807  ['41.9091611', '41.9091643', '-87.6339908', '-...  41.909164 -87.633268
#
#                                            display_name    class         type  \
# 0     South Bell Avenue, Ducktown, McKinley Park, Ch...  highway  residential
# 1     South Calhoun Avenue, Trumbull Park Terrace, S...  highway  residential
# 2     South Calumet Avenue, Greater Grand Crossing, ...  highway  residential
# 3     South Carpenter Street, University Village/Lit...  highway  residential
# 4     South Carpenter Street, University Village/Lit...  highway  residential
# ...                                                 ...      ...          ...
# 1803  West Gunnison Street, Asia on Argyle, Uptown, ...  highway  residential
# 1804                                                NaN      NaN          NaN
# 1805  West 78th Street, Ashburn, Chicago, Lake Towns...  highway  residential
# 1806  West 81st Street, Ashburn, Chicago, Lake Towns...  highway  residential
# 1807  West Burton Place, Gold Coast, Near North Side...  highway  residential
#
#       importance                    road                    neighbourhood  \
# 0        0.62001       South Bell Avenue                         Ducktown
# 1        0.62000    South Calhoun Avenue            Trumbull Park Terrace
# 2        0.62001    South Calumet Avenue           Greater Grand Crossing
# 3        0.62000  South Carpenter Street  University Village/Little Italy
# 4        0.62000  South Carpenter Street  University Village/Little Italy
# ...          ...                     ...                              ...
# 1803     0.62000    West Gunnison Street                   Asia on Argyle
# 1804         NaN                     NaN                              NaN
# 1805     0.62000        West 78th Street                              NaN
# 1806     0.62000        West 81st Street                              NaN
# 1807     0.62000       West Burton Place                       Gold Coast
#
#                suburb
# 0       McKinley Park
# 1       South Deering
# 2     Washington Park
# 3      Near West Side
# 4      Near West Side
# ...               ...
# 1803           Uptown
# 1804              NaN
# 1805          Ashburn
# 1806          Ashburn
# 1807  Near North Side
#
# [1808 rows x 33 columns]

# %%
plt.plot(df["1st Draw"])

# %%
plt.scatter(df["1st Draw"], df["2nd Draw"])

# %%
austin = df[df["suburb"] == "Austin"]

# %%
austin
# Out:
#      Date Sampled                Address  1st Draw  2nd Draw  3rd Draw  \
# 77      10/9/2019   10XX N Massasoit Ave     10.20      5.95      9.20
# 146     8/23/2019   11XX N Massasoit Ave     12.00     11.70     12.70
# 203      7/7/2016     13XX N Monitor Ave      9.96      7.84      9.57
# 219     5/27/2021    14XX N Lockwood Ave      4.60      4.20      3.30
# 220     9/16/2019       14XX N Lorel Ave      7.80      9.15      8.77
# ...           ...                    ...       ...       ...       ...
# 1458    3/30/2022         6XX N Pine Ave     17.60     18.50     19.40
# 1570    12/2/2021      7XX N Latrobe Ave      5.19      5.86      6.01
# 1582    10/1/2019  80XX S Kilpatrick Ave      7.41     13.20     16.90
# 1583    9/29/2021  80XX S Kilpatrick Ave      3.10      3.10      4.60
# 1688    12/3/2019     8XX N Lockwood Ave      6.89      7.29      7.75
#
#       4th Draw  5th Draw  6th Draw  7th Draw  8th Draw  ...        lat  \
# 77        9.83      6.63      6.30      5.50      5.03  ...  41.896626
# 146      24.60     28.90     28.80     29.20     32.60  ...  41.896626
# 203      15.50     25.10     22.60     20.90     21.60  ...  41.903861
# 219       3.40      3.30      3.20      4.00      4.90  ...  41.887694
# 220       9.34      8.83      8.59     11.20     14.70  ...  41.898556
# ...        ...       ...       ...       ...       ...  ...        ...
# 1458     20.60     13.00     11.60     10.90     10.40  ...  41.896695
# 1570      5.62      5.55      5.35      6.06     11.10  ...  41.905948
# 1582     16.70     15.80     15.90     16.70     16.30  ...  41.879283
# 1583      7.00      7.50      6.90      6.70      6.70  ...  41.879283
# 1688      8.03      8.93     11.90     16.30     16.50  ...  41.887694
#
#             lon                                       display_name    class  \
# 77   -87.769108  North Massasoit Avenue, Austin, Chicago, Cook ...  highway
# 146  -87.769108  North Massasoit Avenue, Austin, Chicago, Cook ...  highway
# 203  -87.771783  North Monitor Avenue, Beat 2531, Austin, Chica...  highway
# 219  -87.757778  North Lockwood Avenue, Austin, Chicago, Cook C...  highway
# 220  -87.759430  North Lorel Avenue, Austin, Chicago, Cook Coun...  highway
# ...         ...                                                ...      ...
# 1458 -87.763622  North Pine Avenue, Beat 2532, Austin, Chicago,...  highway
# 1570 -87.757109  North Latrobe Avenue, Beat 2532, Austin, Chica...  highway
# 1582 -87.742770  South Kilpatrick Avenue, Mandell, Austin, Chic...  highway
# 1583 -87.742770  South Kilpatrick Avenue, Mandell, Austin, Chic...  highway
# 1688 -87.757778  North Lockwood Avenue, Austin, Chicago, Cook C...  highway
#
#              type  importance                     road  neighbourhood  suburb  \
# 77    residential     0.62001   North Massasoit Avenue            NaN  Austin
# 146   residential     0.62001   North Massasoit Avenue            NaN  Austin
# 203   residential     0.62001     North Monitor Avenue            NaN  Austin
# 219   residential     0.62000    North Lockwood Avenue            NaN  Austin
# 220   residential     0.62001       North Lorel Avenue            NaN  Austin
# ...           ...         ...                      ...            ...     ...
# 1458  residential     0.62001        North Pine Avenue            NaN  Austin
# 1570  residential     0.62000     North Latrobe Avenue            NaN  Austin
# 1582  residential     0.62000  South Kilpatrick Avenue        Mandell  Austin
# 1583  residential     0.62000  South Kilpatrick Avenue        Mandell  Austin
# 1688  residential     0.62000    North Lockwood Avenue            NaN  Austin
#
#            Mean
# 77     6.605455
# 146   25.309091
# 203   17.760909
# 219    3.700000
# 220   11.298182
# ...         ...
# 1458  12.707273
# 1570   7.176364
# 1582  15.891818
# 1583   5.745455
# 1688  10.774545
#
# [63 rows x 34 columns]

# %%
df["Mean"] = df[["1st Draw", "2nd Draw", "3rd Draw", "4th Draw", "5th Draw", "6th Draw", "7th Draw", "8th Draw", "9th Draw", "10th Draw", "11th Draw"]].mean(axis = 1)

# %%
df["suburb"].unique()
# Out:
# array(['McKinley Park', 'South Deering', 'Washington Park',
#        'Near West Side', 'Loop', 'Brighton Park', nan, 'Grand Boulevard',
#        'Lower West Side', 'Beverly', 'North Lawndale', 'Douglas',
#        'Pullman', 'South Lawndale', 'Englewood', 'East Garfield Park',
#        'Armour Square', 'Bridgeport', 'Humboldt Park', 'Logan Square',
#        'Austin', 'Albany Park', 'Near South Side', 'Lincoln Park',
#        'Morgan Park', 'Washington Heights', 'Auburn Gresham', 'Kenwood',
#        'Hyde Park', 'West Town', 'Gage Park', 'Avondale', 'Rogers Park',
#        'Hermosa', 'West Pullman', 'Calumet Heights', 'South Chicago',
#        'South Shore', 'Edgewater', 'Avalon Park', 'Uptown', 'West Ridge',
#        'Woodlawn', 'Lincoln Square', 'Portage Park', 'Near North Side',
#        'Irving Park', 'Lake View', 'Norwood Park', 'West Garfield Park',
#        'Forest Glen', 'Jefferson Park', 'North Park', 'Montclare',
#        'North Center', 'Hegewisch', 'Chicago Lawn', 'Ashburn',
#        'Edison Park', 'West Lawn', 'New City', 'Clearing', 'Oakland',
#        'Garfield Ridge', 'West Englewood', 'Burnside', 'Riverdale'],
#       dtype=object)

# %%
lst = []
for suburb in df["suburb"].unique():
    mean_series = df[df["suburb"] == suburb, "Mean"]
    med = mean_series.median()
    lst.append((suburb, med))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1803    False
# 1804    False
# 1805    False
# 1806    False
# 1807    False
# Name: suburb, Length: 1808, dtype: bool, 'Mean')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16304\1131929548.py in <module>
#       1 lst = []
#       2 for suburb in df["suburb"].unique():
# ----> 3     mean_series = df[df["suburb"] == suburb, "Mean"]
#       4     med = mean_series.median()
#       5     lst.append((suburb, med))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3634                 #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635                 #  the TypeError.
# -> 3636                 self._check_indexing_error(key)
#    3637                 raise
#    3638
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _check_indexing_error(self, key)
#    5649             # if key is not a scalar, directly raise an error (the code below
#    5650             # would convert to numpy arrays and raise later any way) - GH29926
# -> 5651             raise InvalidIndexError(key)
#    5652
#    5653     @cache_readonly
#
# InvalidIndexError: (0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1803    False
# 1804    False
# 1805    False
# 1806    False
# 1807    False
# Name: suburb, Length: 1808, dtype: bool, 'Mean')
